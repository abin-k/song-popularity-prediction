# %% [raw]
# The dataset include all the songs that have been on the Top 200 Weekly (Global) charts of Spotify in 2020 & 2021.
# The dataset include the following features:

# %% [raw]
# Highest Charting Position: The highest position that the song has been on in the Spotify Top 200 Weekly Global Charts in 2020 & 2021.
# Number of Times Charted: The number of times that the song has been on in the Spotify Top 200 Weekly Global Charts in 2020 & 2021.
# Week of Highest Charting: The week when the song had the Highest Position in the Spotify Top 200 Weekly Global Charts in 2020 & 2021.
# Song Name: Name of the song that has been on in the Spotify Top 200 Weekly Global Charts in 2020 & 2021.
# Song iD: The song ID provided by Spotify (unique to each song).
# Streams: Approximate number of streams the song has.
# Artist: The main artist/ artists involved in making the song.
# Artist Followers: The number of followers the main artist has on Spotify.
# Genre: The genres the song belongs to.
# Release Date: The initial date that the song was released.
# Weeks Charted: The weeks that the song has been on in the Spotify Top 200 Weekly Global Charts in 2020 & 2021.
# Popularity:The popularity of the track. The value will be between 0 and 100, with 100 being the most popular.
# Danceability: Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
# Acousticness: A measure from 0.0 to 1.0 of whether the track is acoustic.
# Energy: Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy.
# Instrumentalness: Predicts whether a track contains no vocals. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content.
# Liveness: Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live.
# Loudness: The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track. Values typical range between -60 and 0 db.
# Speechiness: Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value.
# Tempo: The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
# Valence: A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
# Chord: The main chord of the song instrumental.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, MinMaxScaler,StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import GridSearchCV

from xgboost import XGBRFRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
data = pd.read_csv('spotify_dataset.csv')
data
# Out:
#       Index  Highest Charting Position  Number of Times Charted  \
# 0         1                          1                        8
# 1         2                          2                        3
# 2         3                          1                       11
# 3         4                          3                        5
# 4         5                          5                        1
# ...     ...                        ...                      ...
# 1551   1552                        195                        1
# 1552   1553                        196                        1
# 1553   1554                        197                        1
# 1554   1555                        198                        1
# 1555   1556                        199                        1
#
#      Week of Highest Charting                           Song Name     Streams  \
# 0      2021-07-23--2021-07-30                             Beggin'  48,633,449
# 1      2021-07-23--2021-07-30           STAY (with Justin Bieber)  47,248,719
# 2      2021-06-25--2021-07-02                            good 4 u  40,162,559
# 3      2021-07-02--2021-07-09                          Bad Habits  37,799,456
# 4      2021-07-23--2021-07-30   INDUSTRY BABY (feat. Jack Harlow)  33,948,454
# ...                       ...                                 ...         ...
# 1551   2019-12-27--2020-01-03                           New Rules   4,630,675
# 1552   2019-12-27--2020-01-03                  Cheirosa - Ao Vivo   4,623,030
# 1553   2019-12-27--2020-01-03           Havana (feat. Young Thug)   4,620,876
# 1554   2019-12-27--2020-01-03          Surtada - Remix Brega Funk   4,607,385
# 1555   2019-12-27--2020-01-03  Lover (Remix) [feat. Shawn Mendes]   4,595,450
#
#                              Artist Artist Followers                 Song ID  \
# 0                          Måneskin          3377762  3Wrjm47oTz2sjIgck11l5e
# 1                     The Kid LAROI          2230022  5HCyWlXZPP0y6Gqq8TgA20
# 2                    Olivia Rodrigo          6266514  4ZtFanR9U6ndgddUvNcjcG
# 3                        Ed Sheeran         83293380  6PQ88X9TkUIAUIZJHW2upE
# 4                         Lil Nas X          5473565  27NovPIUIRrOZoCHxABJwK
# ...                             ...              ...                     ...
# 1551                       Dua Lipa         27167675  2ekn2ttSfGqwhhate0LSR0
# 1552                 Jorge & Mateus         15019109  2PWjKmjyTZeDpmOUa3a5da
# 1553                 Camila Cabello         22698747  1rfofaqEpACxVEHIZBJe6W
# 1554  Dadá Boladão, Tati Zaqui, OIK           208630  5F8ffc8KWKNawllr5WsW0r
# 1555                   Taylor Swift         42227614  3i9UVldZOE0aD0JnyfAZZ0
#
#                                                   Genre  ... Danceability  \
# 0                ['indie rock italiano', 'italian pop']  ...        0.714
# 1                                ['australian hip hop']  ...        0.591
# 2                                               ['pop']  ...        0.563
# 3                                     ['pop', 'uk pop']  ...        0.808
# 4                         ['lgbtq+ hip hop', 'pop rap']  ...        0.736
# ...                                                 ...  ...          ...
# 1551                     ['dance pop', 'pop', 'uk pop']  ...        0.762
# 1552           ['sertanejo', 'sertanejo universitario']  ...        0.528
# 1553  ['dance pop', 'electropop', 'pop', 'post-teen ...  ...        0.765
# 1554                     ['brega funk', 'funk carioca']  ...        0.832
# 1555                           ['pop', 'post-teen pop']  ...        0.448
#
#      Energy Loudness Speechiness Acousticness Liveness    Tempo Duration (ms)  \
# 0       0.8   -4.808      0.0504        0.127    0.359  134.002        211560
# 1     0.764   -5.484      0.0483       0.0383    0.103  169.928        141806
# 2     0.664   -5.044       0.154        0.335   0.0849  166.928        178147
# 3     0.897   -3.712      0.0348       0.0469    0.364  126.026        231041
# 4     0.704   -7.409      0.0615       0.0203   0.0501  149.995        212000
# ...     ...      ...         ...          ...      ...      ...           ...
# 1551    0.7   -6.021      0.0694      0.00261    0.153  116.073        209320
# 1552   0.87   -3.123      0.0851         0.24    0.333   152.37        181930
# 1553  0.523   -4.333        0.03        0.184    0.132  104.988        217307
# 1554   0.55   -7.026      0.0587        0.249    0.182  154.064        152784
# 1555  0.603   -7.176       0.064        0.433   0.0862  205.272        221307
#
#      Valence  Chord
# 0      0.589      B
# 1      0.478  C#/Db
# 2      0.688      A
# 3      0.591      B
# 4      0.894  D#/Eb
# ...      ...    ...
# 1551   0.608      A
# 1552   0.714      B
# 1553   0.394      D
# 1554   0.881      F
# 1555   0.422      G
#
# [1556 rows x 23 columns]

# %%
data.isnull().sum()
# Out:
# Index                        0
# Highest Charting Position    0
# Number of Times Charted      0
# Week of Highest Charting     0
# Song Name                    0
# Streams                      0
# Artist                       0
# Artist Followers             0
# Song ID                      0
# Genre                        0
# Release Date                 0
# Weeks Charted                0
# Popularity                   0
# Danceability                 0
# Energy                       0
# Loudness                     0
# Speechiness                  0
# Acousticness                 0
# Liveness                     0
# Tempo                        0
# Duration (ms)                0
# Valence                      0
# Chord                        0
# dtype: int64

# %%
data = data.drop(['Index','Week of Highest Charting','Song Name','Streams','Song ID','Weeks Charted'],axis=1)
data.head()
# Out:
#    Highest Charting Position  Number of Times Charted          Artist  \
# 0                          1                        8        Måneskin
# 1                          2                        3   The Kid LAROI
# 2                          1                       11  Olivia Rodrigo
# 3                          3                        5      Ed Sheeran
# 4                          5                        1       Lil Nas X
#
#   Artist Followers                                   Genre Release Date  \
# 0          3377762  ['indie rock italiano', 'italian pop']   2017-12-08
# 1          2230022                  ['australian hip hop']   2021-07-09
# 2          6266514                                 ['pop']   2021-05-21
# 3         83293380                       ['pop', 'uk pop']   2021-06-25
# 4          5473565           ['lgbtq+ hip hop', 'pop rap']   2021-07-23
#
#   Popularity Danceability Energy Loudness Speechiness Acousticness Liveness  \
# 0        100        0.714    0.8   -4.808      0.0504        0.127    0.359
# 1         99        0.591  0.764   -5.484      0.0483       0.0383    0.103
# 2         99        0.563  0.664   -5.044       0.154        0.335   0.0849
# 3         98        0.808  0.897   -3.712      0.0348       0.0469    0.364
# 4         96        0.736  0.704   -7.409      0.0615       0.0203   0.0501
#
#      Tempo Duration (ms) Valence  Chord
# 0  134.002        211560   0.589      B
# 1  169.928        141806   0.478  C#/Db
# 2  166.928        178147   0.688      A
# 3  126.026        231041   0.591      B
# 4  149.995        212000   0.894  D#/Eb

# %%
Artist=data['Artist'].value_counts()
Artist=pd.DataFrame(Artist)
Artist
# Out:
#                                Artist
# Taylor Swift                       52
# Lil Uzi Vert                       32
# Justin Bieber                      32
# Juice WRLD                         30
# Pop Smoke                          29
# ...                               ...
# Chris Brown, Young Thug             1
# Rauw Alejandro, J Balvin            1
# 347aidan                            1
# Migrantes, Alico                    1
# Dadá Boladão, Tati Zaqui, OIK       1
#
# [716 rows x 1 columns]

# %%
Artist.size
# Out:
# 716

# %%
Genre=data['Genre'].value_counts()
Genre=pd.DataFrame(Genre)
Genre
# Out:
#                                                     Genre
# []                                                     75
# ['dance pop', 'pop', 'post-teen pop']                  71
# ['latin', 'reggaeton', 'trap latino']                  63
# ['pop', 'post-teen pop']                               57
# ['melodic rap', 'philly rap', 'rap', 'trap']           33
# ...                                                   ...
# ['trap queen']                                          1
# ['dream smp', 'viral rap']                              1
# ['disco', 'europop', 'new romantic', 'new wave'...      1
# ['adult standards', 'brill building pop', 'easy...      1
# ['gangster rap', 'hip hop', 'pop rap', 'rap', '...      1
#
# [395 rows x 1 columns]

# %%
Genre.size
# Out:
# 395

# %%
Genre_count=Genre[Genre.Genre==1]
Genre_count.size
# Out:
# 213

# %%
Chord=data['Chord'].value_counts()
Chord=pd.DataFrame(Chord)
Chord
# Out:
#        Chord
# C#/Db    214
# C        155
# B        141
# G        136
# F        131
# G#/Ab    130
# D        125
# A#/Bb    122
# F#/Gb    121
# A        118
# E        112
# D#/Eb     40
#           11

# %%
Chord.size
# Out:
# 13

# %%
data.head()
# Out:
#    Highest Charting Position  Number of Times Charted          Artist  \
# 0                          1                        8        Måneskin
# 1                          2                        3   The Kid LAROI
# 2                          1                       11  Olivia Rodrigo
# 3                          3                        5      Ed Sheeran
# 4                          5                        1       Lil Nas X
#
#   Artist Followers                                   Genre Release Date  \
# 0          3377762  ['indie rock italiano', 'italian pop']   2017-12-08
# 1          2230022                  ['australian hip hop']   2021-07-09
# 2          6266514                                 ['pop']   2021-05-21
# 3         83293380                       ['pop', 'uk pop']   2021-06-25
# 4          5473565           ['lgbtq+ hip hop', 'pop rap']   2021-07-23
#
#   Popularity Danceability Energy Loudness Speechiness Acousticness Liveness  \
# 0        100        0.714    0.8   -4.808      0.0504        0.127    0.359
# 1         99        0.591  0.764   -5.484      0.0483       0.0383    0.103
# 2         99        0.563  0.664   -5.044       0.154        0.335   0.0849
# 3         98        0.808  0.897   -3.712      0.0348       0.0469    0.364
# 4         96        0.736  0.704   -7.409      0.0615       0.0203   0.0501
#
#      Tempo Duration (ms) Valence  Chord
# 0  134.002        211560   0.589      B
# 1  169.928        141806   0.478  C#/Db
# 2  166.928        178147   0.688      A
# 3  126.026        231041   0.591      B
# 4  149.995        212000   0.894  D#/Eb

# %%
data.dtypes
# Out:
# Highest Charting Position     int64
# Number of Times Charted       int64
# Artist                       object
# Artist Followers             object
# Genre                        object
# Release Date                 object
# Popularity                   object
# Danceability                 object
# Energy                       object
# Loudness                     object
# Speechiness                  object
# Acousticness                 object
# Liveness                     object
# Tempo                        object
# Duration (ms)                object
# Valence                      object
# Chord                        object
# dtype: object

# %%
print(data['Artist'].unique())
print('************')
print(data['Genre'].unique())
print('************')
print(data['Chord'].unique())
# Out:
# ['Måneskin' 'The Kid LAROI' 'Olivia Rodrigo' 'Ed Sheeran' 'Lil Nas X'
#  'Doja Cat' 'Rauw Alejandro' 'Bad Bunny' 'Dua Lipa'
#  'J Balvin, Maria Becerra' 'BTS' 'Justin Bieber' 'The Weeknd'
#  'Nio Garcia, J Balvin, Bad Bunny' 'Mora, Bad Bunny, Sech' 'Glass Animals'
#  'Farruko' 'Post Malone' 'Riton, Nightcrawlers' 'Masked Wolf'
#  'Bruno Mars, Anderson .Paak, Silk Sonic' 'Camila Cabello'
#  'Sebastian Yatra, Myke Towers' 'Harry Styles' 'Polo G'
#  'Doja Cat, The Weeknd' 'Sech, Jhay Cortez' 'Bad Bunny, Jhay Cortez'
#  'TINI, Maria Becerra'
#  'J Balvin, KAROL G, Nicky Jam, Crissin, Totoy El Frio, Natan & Shander'
#  'Tiësto' 'Galantis' '24kGoldn' 'Tiago PZK, LIT killah'
#  'Wisin, Jhay Cortez, Anuel AA, Los Legendarios, Myke Towers'
#  'Bella Poarch' 'Bizarrap, Nicky Jam'
#  'Marc Seguí, Rauw Alejandro, Pol Granch' 'Billie Eilish'
#  'Majestic, Boney M.' 'Marshmello' 'Surf Curse' 'João Gomes'
#  'Rauw Alejandro, Mr. Naisgai' 'Maroon 5' 'OneRepublic'
#  'Megan Thee Stallion' 'ATB, Topic, A7S' 'Giveon' 'Trinidad Cardona'
#  'The Neighbourhood' 'Maluma' 'Lewis Capaldi' 'Smiley' 'Sleepy Hallow'
#  'KAROL G, Mariah Angeliq' 'Justin Quiles, Chimbala, Zion & Lennox'
#  'Shouse' 'Kali Uchis' 'Gera MX, Christian Nodal'
#  'Los Legendarios, Wisin, Jhay Cortez' 'Tones And I' 'Drake' 'Bo Burnham'
#  'Travis Scott, HVME' 'Joel Corry' 'Joel Corry, RAYE, David Guetta'
#  'Justin Wellington, Small Jam' 'Belly, The Weeknd, Young Thug'
#  'Duncan Laurence' 'Mora, Jhay Cortez' 'Ariana Grande'
#  'RAF Camora, Bonez MC' 'Natti Natasha, Becky G' 'J Balvin, Skrillex'
#  'WILLOW' 'Dave' 'Madison Beer' 'BANDIDO' 'Imagine Dragons'
#  'Internet Money' 'Bruno Mars' 'SAINt JHN' 'Sech' 'Becky G, El Alfa'
#  'Ingratax' 'Post Malone, Swae Lee' 'dhruv' 'Calvin Harris' 'Luan Santana'
#  'Shawn Mendes, Camila Cabello' 'MYA, TINI, Duki' 'Bad Bunny, ROSALÍA'
#  'DaBaby' 'Conan Gray' 'Tate McRae' 'Avicii' 'Vance Joy' 'Nirvana'
#  'Trippie Redd' 'Tom Odell' 'Jamie Miller' 'Hozier' 'Tom Grennan'
#  'Gusttavo Lima' 'Cardi B' 'Khalid' 'Queen' 'Myke Towers, Juhn' 'MEDUZA'
#  'Travis Scott' 'Ofenbach' 'Camilo, Shawn Mendes'
#  'Lady Gaga, Bradley Cooper' 'Cochise, $NOT' 'Mari Fernandez' 'Coldplay'
#  'Emilia, Duki' 'João Gomes, Vitor Fernandes'
#  'Matheus Fernandes, Dilsinho' 'Vegedream' 'Pop Smoke' 'AURORA'
#  'Juice WRLD' 'Lil Tjay, 6LACK' 'P!nk, Willow Sage Hart' 'The Killers'
#  'The Police' 'Fleetwood Mac' 'James Arthur' 'Normani'
#  'Powfu, beabadoobee' 'Anne-Marie, Niall Horan' 'Drake, WizKid, Kyla'
#  'Sarah Cothran' 'Walker Hayes' 'John Legend' 'Saweetie' 'SZA'
#  'Anne-Marie, Little Mix' 'Blxst, Tyga' 'MC Zaquin, MC Rick' 'Topic, A7S'
#  'Luísa Sonza' 'Roddy Ricch' 'Eminem' 'Trippie Redd, Lil Uzi Vert' 'KSI'
#  'Tyler, The Creator' 'Pashanim' 'Tion Wayne, Russ Millions'
#  'Nio Garcia, Flow La Movie' 'BLANCO, Sfera Ebbasta' 'Regard' 'John Mayer'
#  'Mc Davi, Mc Pedrinho, Mc Don Juan' 'Selena Gomez' 'Bas'
#  'Israel & Rodolffo, Wesley Safadão' 'TWICE' 'BIA' 'Kane Brown, blackbear'
#  'Alex Rose, Rauw Alejandro' 'Dj Guuga, DJ Ivis'
#  'Maluma, Beéle, Rauw Alejandro, Mambo Kingz, DJ Luian, Darell'
#  'The Chainsmokers, Halsey' 'Oasis' 'Brent Faiyaz' 'Big Red Machine'
#  'DJ Khaled' 'StarBoi3' 'Lorde' 'Shirin David' 'CJ' 'Israel & Rodolffo'
#  'Miley Cyrus' 'Gym Class Heroes' 'Rauw Alejandro, Anuel AA' 'sangiovanni'
#  'Bizarrap, Eladio Carrion' 'Arctic Monkeys' 'Migos'
#  'Fedez, Achille Lauro' 'J Balvin, Dua Lipa, Bad Bunny'
#  'Jawsh 685, Jason Derulo' 'Crissin, Totoy El Frio, Natan & Shander'
#  'Boza' 'Tate McRae, Khalid' 'Soso Maness' 'J. Cole' 'XXXTENTACION'
#  'Nathan Evans' 'Macklemore & Ryan Lewis' 'Machine Gun Kelly'
#  'Martin Garrix' 'Rochy RD, Myke Towers, Nicki Nicole' 'Linkin Park'
#  'The Chainsmokers, Coldplay' 'Regard, Troye Sivan, Tate McRae' 'Ava Max'
#  'Black Eyed Peas, Shakira' 'MC Kevin o Chris' 'Lady Gaga'
#  'Lil Baby, Lil Durk' 'TOMORROW X TOGETHER, Seori' 'Lil Tecca'
#  'Young Stoner Life, Young Thug, Gunna'
#  'Manuel Turizo, Rauw Alejandro, Myke Towers' 'KAROL G' 'Ashnikko'
#  'Alok, Mc Don Juan, Dj GBR' 'Malu, DJ Lucas Beat' 'Lil Mosey'
#  'Gotye, Kimbra' 'Mc Poze do Rodo, Neo Beats, Mainstreet' 'Barbara Pravi'
#  'Twenty One Pilots' 'Nicki Minaj' 'Blind Channel' 'Go_A' 'ITZY'
#  'Joyner Lucas, Lil Baby' 'Beach Bunny' "Gjon's Tears" 'Lil Tjay' 'Dream'
#  'Daði Freyr' 'Bizarrap, Snow Tha Product'
#  'Nio Garcia, Casper Magico, Ozuna, Wisin & Yandel, Myke Towers, Flow La Movie'
#  'MARINA' 'Myke Towers'
#  'Milly, Farruko, Nio Garcia, Jay Wheeler, Amenazzy' 'Daddy Yankee'
#  'JP Saxe' 'Russ Millions, Tion Wayne' 'Don Toliver' 'Bizarrap, L-Gante'
#  'Pink Sweat$' 'Future' '187 Strassenbande, Bonez MC, Frauenarzt'
#  'Nicky Jam, Romeo Santos' 'Raí Saia Rodada' 'Camilo, Evaluna Montaner'
#  'Jorge & Mateus' 'ElyOtto' 'Baby Keem' 'Anitta' 'ROSÉ' 'Taylor Swift'
#  'J Balvin, Khalid' 'Demi Lovato' 'Pooh Shiesty'
#  'Wisin, Myke Towers, Los Legendarios' 'H.E.R.' 'HVME' 'Ritt Momney'
#  'Diego & Victor Hugo, Bruno & Marrone' 'Shawn Mendes' 'Mimi Webb'
#  'blackbear' 'KAROL G, Anuel AA, J Balvin'
#  'Wesley Safadão, Os Barões Da Pisadinha' 'Os Barões Da Pisadinha'
#  'J Balvin, Bad Bunny' 'DMX' 'Sebastian Yatra, Guaynaa'
#  'Sech, Daddy Yankee, J Balvin, ROSALÍA, Farruko' 'KHEA, Duki'
#  'Sam Fischer, Demi Lovato' 'Kevin Roldan, Bryant Myers, Lyanno'
#  'Jason Derulo' 'Mother Mother' 'DJ Ivis'
#  'Rusherking, KHEA, Duki, Maria Becerra, LIT killah, Tiago PZK'
#  'Maroon 5, Wiz Khalifa' 'Jack Harlow' 'a-ha' 'Camilo, El Alfa' 'Rod Wave'
#  'J Balvin' 'KAROL G, Nicki Minaj' 'Ozuna, J Balvin, Chencho Corleone'
#  'Zoe Wees' 'DJ Ivis, Tarcísio do Acordeon' 'Jason Derulo, Nuka'
#  'The Weeknd, Daft Punk' 'Hugo & Guilherme' 'Lana Del Rey'
#  'Nicky Jam, Myke Towers' 'Maluma, Lenny Tavárez' 'Camilo'
#  'Hippie Sabotage' 'Justin Quiles' 'DJ Snake' 'Sia'
#  'Jay Wheeler, DJ Nelson, Myke Towers' 'Robin Schulz' 'Tame Impala'
#  'BANNERS' 'Pamungkas' 'BLACKPINK' 'NF, Hopsin' 'Madame'
#  'Francesca Michielin, Fedez' 'Anuel AA, Ozuna' 'Booba, JSX' 'Lil Baby'
#  'Lele Pons' 'Ofenbach, Quarterhead' 'Lil Peep' 'BØRNS'
#  'C. Tangana, Niño de Elche, La Húngara' 'Arizona Zervas'
#  'C. Tangana, Ed Maverick' 'Halsey' 'Clairo' 'Bausa, Apache 207' 'NF'
#  'Sabrina Carpenter' 'Sara Kays' 'Jason Derulo, Maroon 5' 'Ozuna, Camilo'
#  'Bizarrap, Nathy Peluso' 'Maluma, The Weeknd' 'Tarcísio do Acordeon'
#  'Surf Mesa' 'Sia, David Guetta' 'benny blanco' 'Bring Me The Horizon'
#  'Kawe, Mc Lele JP' 'Dean Lewis' 'Jerry Di'
#  'KASIMIR1441, badmómzjay, WILDBWOYS' 'Brent Faiyaz, DJ Dahi' 'ZAYN'
#  'Morgan Wallen' 'Nio Garcia, Anuel AA, Myke Towers, Brray, Juanka'
#  'Migrantes, Alico' 'Sam Smith' '347aidan' 'Rauw Alejandro, J Balvin'
#  'Chris Brown, Young Thug' 'Juice WRLD, The Kid LAROI'
#  'Anne-Marie, KSI, Digital Farm Animals'
#  'Luísa Sonza, Pabllo Vittar, Anitta' 'Erica Banks' 'Ozuna' 'Fousheé'
#  'Sech, J Balvin' 'Dua Lipa, Angèle' 'Apache 207' 'Surfaces'
#  'Petter Ferraz, Menor Nico' 'Marshmello, Bastille'
#  'Os Barões Da Pisadinha, Xand Avião' 'Kid Cudi'
#  'MEDUZA, Becky Hill, Goodboys' 'CORPSE, Savage Ga$p' 'Mariah Carey'
#  'Wham!' 'Brenda Lee' 'Bobby Helms' 'Michael Bublé' 'Andy Williams'
#  'Kelly Clarkson' 'José Feliciano' 'Dean Martin' 'Frank Sinatra'
#  'The Ronettes' 'Band Aid' 'Paul McCartney' 'John Lennon, Yoko Ono'
#  'Chris Rea' 'Nat King Cole'
#  'Bing Crosby, Ken Darby Singers, John Scott Trotter & His Orchestra'
#  'Playboi Carti' 'Burl Ives' 'The Pogues' "Shakin' Stevens"
#  'Elvis Presley' 'Chuck Berry' 'The Jackson 5' 'Kylie Minogue'
#  'Perry Como, The Fontane Sisters' 'Darlene Love' 'Elton John'
#  'Jonas Esticado' 'Daryl Hall & John Oates' 'Britney Spears'
#  'Brett Eldredge' 'Jonas Brothers' 'Gwen Stefani' 'Idina Menzel'
#  'Eartha Kitt, Henri Rene & His Orchestra'
#  'Mykola Dmytrovych Leontovych, John Williams' 'Stevie Wonder'
#  'Bruce Springsteen' 'Leona Lewis' 'The Beach Boys' 'Liam Payne'
#  'Meghan Trainor' 'Bing Crosby' 'Pentatonix' 'Donny Hathaway'
#  'Tony Bennett' 'Katy Perry' '*NSYNC' 'Eagles' 'Tory Lanez, Jack Harlow'
#  'salem ilese' 'Bad Bunny, Jowell & Randy, Ñengo Flow' 'Studio Killers'
#  'Bad Bunny, ABRA' 'Trio Vegabajeño' 'Jhay Cortez, Bad Bunny'
#  'Sfera Ebbasta' 'Clean Bandit, Mabel' 'Christian Nodal, Ángela Aguilar'
#  'Master KG' 'Tainy' 'Aya Nakamura' 'Justin Timberlake'
#  '21 Savage, Metro Boomin' 'Wallows' 'Dan + Shay' 'Vedo' 'Manuel Turizo'
#  'StaySolidRocky' 'Future, Lil Uzi Vert' 'Kane Brown'
#  'K/DA, Madison Beer, (G)I-DLE, Lexie Liu, Jaira Burns, Seraphine, League of Legends'
#  'Octavian, Skepta' 'Ty Dolla $ign' 'Little Mix' 'MAX'
#  'Nelly Furtado, Timbaland' 'Labrinth' 'Anuel AA, Bad Bunny' 'Kina' 'DDG'
#  'Luke Combs' 'Super Yei, Jone Quest' 'Joji'
#  'Daddy Yankee, Anuel AA, Kendo Kaponi' 'Cali Y El Dandee, Danna Paola'
#  'KHEA' 'Ozuna, KAROL G, Myke Towers' 'Michael Jackson' 'Bonez MC' 'AC/DC'
#  'Money Man' 'Big Sean' 'Black Eyed Peas, Ozuna, J. Rey Soul'
#  'Lauv, Conan Gray' 'Marshmello, Demi Lovato'
#  'THE SCOTTS, Travis Scott, Kid Cudi' 'Trueno, Bizarrap, Taiu, TATOOL'
#  'Passenger' 'Melanie Martinez' 'Kygo, OneRepublic' 'Adele' 'Ali Gatie'
#  'Curtis Waters' 'G-Eazy'
#  '13 Organisé, SCH, Kofs, Jul, Naps, Soso Maness, Elams, Solda, Houari'
#  'Bebe Rexha' 'ROSALÍA' 'Gunna' 'Rauw Alejandro, Dalex, Lenny Tavárez'
#  'Noah Cyrus' 'BENEE, Gus Dapperton' 'Niack'
#  'Feid, J Balvin, Justin Quiles' 'Chris Brown' 'Bryson Tiller' 'WhoHeem'
#  'Joji, Diplo' 'Bea Miller' 'Joji, BENEE' 'Dalex' 'Juice WRLD, Polo G'
#  'Harry Nach' 'Kendrick Lamar, Jay Rock' 'Internet Money, Diplo'
#  'Earth, Wind & Fire' 'Regard, RAYE' 'Damso, Hamza' 'Damso' '6ix9ine'
#  'Kygo, Donna Summer' 'Ozuna, Doja Cat, Sia'
#  'SZA, The Neptunes, Pharrell Williams, Ty Dolla $ign' 'Matuê'
#  'Alex Rose, Rafa Pabön' 'Bonez MC, Maxwell' 'Headie One' 'Nea'
#  'Beyoncé, Megan Thee Stallion' 'Robin Schulz, Wes'
#  'K/DA, (G)I-DLE, Wolftyla, Bea Miller, League of Legends'
#  'Mc Zaac, Anitta, Tyga' 'Peach Tree Rascals' 'Black Eyed Peas, J Balvin'
#  'KitschKrieg, Jamule, SFR' 'Kygo, Tina Turner' 'Conkarah' 'Cordae'
#  'JACKBOYS, Travis Scott' 'Jowell & Randy, J Balvin' 'Anuel AA'
#  'Justin Quiles, Daddy Yankee, El Alfa'
#  'Internet Money, Gunna, Don Toliver, NAV' 'Capital Bra, Cro'
#  'Feid, Justin Quiles' 'Bausa, Juju' 'Mustard' 'Jason Mraz'
#  '5 Seconds of Summer' 'S1mba' 'Headie One, Drake'
#  'Rauw Alejandro, Chencho Corleone' 'Jason Derulo, Puri, Jhorrmountain'
#  'twocolors' 'Kygo, Whitney Houston' 'Juanfran' 'NLE Choppa'
#  'VIZE, Tom Gregory' 'A$AP Ferg' 'El Alfa, Chael Produciendo'
#  'Capital Bra, Clueso, KC Rebell' 'One Direction' 'Ufo361, Sonus030'
#  'DripReport' 'Logic' 'StaySolidRocky, Lil Uzi Vert' 'Trevor Daniel'
#  'Luciano' 'Lil Nas X, Billy Ray Cyrus'
#  'Anuel AA, Daddy Yankee, KAROL G, Ozuna, J Balvin'
#  'Dalex, Lenny Tavárez, Chencho Corleone, Juhn, Dímelo Flow'
#  'Bad Bunny, Sech' 'Dímelo Flow, Arcangel, Sech' 'Kontra K'
#  'Kanye West, Travis Scott' 'Red Velvet - IRENE & SEULGI' 'Sam Fischer'
#  'Y2K, bbno$' 'Sleepy Hallow, Fousheé' 'Tyla Yaweh' 'iann dior'
#  'Jhay Cortez, J Balvin, Bad Bunny'
#  'Rauw Alejandro, Chencho Corleone, KEVVO, Bryant Myers, Lyanno, Dalex'
#  'Journey' 'Beyoncé' 'Miksu / Macloud, Summer Cem, Luciano, Jamule'
#  'Lil Uzi Vert' 'Lauv' 'Panic! At The Disco'
#  'Boomdabash, Alessandra Amoroso' 'Khalid, Disclosure'
#  'Bad Bunny, Don Omar' 'Tyga' 'Capital Bra, Bozza'
#  'A Boogie Wit da Hoodie' 'Bosh' 'Alida, Robin Schulz' 'Alexander 23'
#  'MEDUZA, Goodboys' 'Bad Bunny, Daddy Yankee' 'PUBLIC'
#  'Pop Smoke, Rowdy Rebel' 'Shablo' 'Ufo361, CÉLINE' 'Natalie Taylor' 'NAV'
#  'Kygo, Zara Larsson, Tyga' 'Alec Benjamin' 'PARTYNEXTDOOR, Rihanna'
#  'KC Rebell, Summer Cem' 'Childish Gambino' 'Rauw Alejandro, Farruko'
#  'Bad Bunny, Nicky Jam' 'Bad Bunny, Tainy' 'YNW Melly' 'Kygo, Kim Petras'
#  'AK AUSSERKONTROLLE, Bonez MC' 'KALIM, Ufo361' 'Lil Yachty'
#  'Kygo, Zak Abel' 'Agust D' 'Capital Bra' 'Yandel, Bad Bunny'
#  'Bad Bunny, Zion & Lennox' 'IU' 'Vicetone, Tony Igy'
#  'Arcangel, Sech, Romeo Santos' 'jxdn' 'Sech, Daddy Yankee'
#  'Nicky Jam, Daddy Yankee'
#  'Polo G, Stunna 4 Vegas, NLE Choppa, Mike WiLL Made-It'
#  'G Herbo, Juice WRLD, Lil Uzi Vert, Chance the Rapper'
#  'Trippie Redd, PARTYNEXTDOOR' 'Kina, Adriana Proenza'
#  'Bad Bunny, Gabriela' 'Banda MS de Sergio Lizárraga, Snoop Dogg'
#  'Capital Bra, Loredana' 'Ashe' 'Kehlani' 'Future, Drake, Young Thug'
#  'NAV, Gunna' 'Ufo361' 'Tory Lanez'
#  'Rauw Alejandro, Anuel AA, Natti Natasha, Farruko, Lunay' 'BROCKHAMPTON'
#  'Shakira, Anuel AA' 'The 1975' 'Alan Walker, Ava Max'
#  'Camilo, Pedro Capó' 'Ellie Goulding' 'Rvssian, Anuel AA, Juice WRLD'
#  'Kygo, Sasha Alex Sloan' 'KAROL G, Anuel AA' 'Dominic Fike' 'Samra'
#  'The Chainsmokers, ILLENIUM, Lennon Stella'
#  'Lunay, Myke Towers, Ozuna, Chencho Corleone, Rauw Alejandro'
#  'Polo G, Stunna 4 Vegas' 'Sub Urban' 'Lizzo' 'Bazzi' 'Shiva, Eiffel 65'
#  'Zuna, Loredana, SRNO' 'Bad Bunny, Yaviah'
#  'Jhay Cortez, Anuel AA, J Balvin' 'J Balvin, Sky Rompiendo' 'Niall Horan'
#  'J Balvin, Mr Eazi' 'Dardan, Monet192' 'Christian Nodal' 'Jhené Aiko'
#  'Bad Bunny, Anuel AA' 'Lil Uzi Vert, 21 Savage'
#  'Bad Bunny, Duki, Pablo Chill-E' 'Ninho' 'Bad Bunny, Ñengo Flow'
#  'Bad Bunny, Mora' 'SZA, Justin Timberlake' 'Nicky Jam, Anuel AA'
#  'Henrique & Juliano' 'Residente' 'Bad Bunny, Kendo Kaponi, Arcangel'
#  'Lauv, Troye Sivan' 'Bad Bunny, Myke Towers' 'Daddy Yankee, Sech'
#  'Lunay, Ozuna, Anuel AA' 'Lauv, LANY'
#  'Dalex, Lenny Tavárez, Anitta, Natti Natasha, Farruko, Justin Quiles'
#  'Arcangel, Bad Bunny' 'TOKYO’S REVENGE' 'Stormzy' 'Capital Bra, Samra'
#  'Rich Music LTD, Sech, Dalex, Justin Quiles, Lenny Tavárez, Feid, Wisin, Zion'
#  'Lunay, Daddy Yankee, Bad Bunny' 'SHAED'
#  'Thiaguinho MT, Mila, JS o Mão de Ouro'
#  'Rich Music LTD, Sech, Dalex, Justin Quiles, Lenny Tavárez, Feid'
#  'PEDRO SAMPAIO, Felipe Original, JS o Mão de Ouro' 'K CAMP' 'Sech, Ozuna'
#  'Major Lazer, Diplo' 'Reik, J Balvin, Lalo Ebratt' 'Dalex, Sech'
#  'Migos, Travis Scott, Young Thug' 'Kygo, Sandro Cavazza'
#  'Joker Bra, VIZE' 'Mac Miller' 'Justin Bieber, Quavo' 'Ant Saunders'
#  'Anne-Marie' 'Lil Wayne' 'Justin Bieber, Kehlani' 'ROSALÍA, Ozuna'
#  'Justin Quiles, Natti Natasha, Farruko' 'Piso 21, Christian Nodal'
#  'DJ Snake, J Balvin' 'Red Velvet' 'ROSALÍA, J Balvin, El Guincho'
#  'Travis Scott, Young Thug' 'Daddy Yankee, Snow'
#  'Sech, Ozuna, Anuel AA, Darell, Nicky Jam' 'Matthew Wilder'
#  'Juju, Loredana, Miksu / Macloud' 'Riton, Oliver Heldens' 'Shakira'
#  'Meek Mill' 'J. Cole, Young Thug' 'Gzuz' 'Samra, ELIF' 'Murda, Ezhel'
#  'Sam Feldt' 'Ufo361, Future' 'Gambi' 'Maes, Booba' 'Idina Menzel, AURORA'
#  'Mabel' 'Trippie Redd, DaBaby' 'Pedro Capó, Farruko'
#  'The Chainsmokers, Kygo' 'JACKBOYS, Sheck Wes' 'French Montana'
#  'SHAED, ZAYN' 'JACKBOYS, Pop Smoke, Travis Scott' 'JACKBOYS'
#  'Anitta, Lexa, Luísa Sonza' "Gradur, Heuss L'enfoiré"
#  'Dadá Boladão, Tati Zaqui, OIK']
# ************
# ["['indie rock italiano', 'italian pop']" "['australian hip hop']"
#  "['pop']" "['pop', 'uk pop']" "['lgbtq+ hip hop', 'pop rap']"
#  "['dance pop', 'pop']" "['puerto rican pop', 'trap latino']"
#  "['latin', 'reggaeton', 'trap latino']" "['dance pop', 'pop', 'uk pop']"
#  "['latin', 'reggaeton', 'reggaeton colombiano']"
#  "['k-pop', 'k-pop boy group']" "['canadian pop', 'pop', 'post-teen pop']"
#  "['canadian contemporary r&b', 'canadian pop', 'pop']"
#  "['reggaeton', 'trap latino']"
#  "['gauze pop', 'indietronica', 'shiver pop']"
#  "['latin', 'latin hip hop', 'reggaeton', 'trap latino']"
#  "['dfw rap', 'melodic rap', 'rap']"
#  "['dance pop', 'house', 'pop dance', 'tropical house', 'uk dance']"
#  "['dance pop', 'pop', 'post-teen pop']"
#  "['dance pop', 'electropop', 'pop', 'post-teen pop']"
#  "['colombian pop', 'latin', 'reggaeton', 'reggaeton colombiano']"
#  "['pop', 'post-teen pop']" ' ' "['chicago rap']"
#  "['latin', 'panamanian pop', 'reggaeton', 'trap latino']"
#  "['latin pop', 'pop argentino']"
#  "['big room', 'brostep', 'dance pop', 'dutch edm', 'edm', 'electro house', 'house', 'pop dance', 'slap house', 'trance', 'tropical house']"
#  "['dance pop', 'edm', 'electro house', 'pop', 'pop dance', 'tropical house']"
#  "['cali rap']" "['trap argentino']" '[]'
#  "['argentine hip hop', 'pop venezolano', 'trap argentino', 'trap latino']"
#  "['electropop', 'pop']" "['house', 'pop dance', 'uk dance']"
#  "['brostep', 'edm', 'pop', 'pop dance', 'progressive electro house']"
#  "['dreamo', 'indie surf', 'surf punk', 'vegas indie']"
#  "['pop', 'pop rock']" "['dance pop', 'piano rock', 'pop', 'pop rock']"
#  "['houston rap', 'pop', 'pop rap', 'trap queen']"
#  "['german dance', 'german techno', 'german trance', 'trance']"
#  "['pop', 'r&b']" "['modern alternative rock', 'modern rock', 'pop']"
#  "['canadian hip hop', 'toronto rap']" "['brooklyn drill', 'nyc rap']"
#  "['aussietronica']" "['colombian pop', 'pop']"
#  "['mexican hip hop', 'rap conciencia']" "['australian pop', 'pop']"
#  "['canadian hip hop', 'canadian pop', 'hip hop', 'pop rap', 'rap', 'toronto rap']"
#  "['comic']" "['rap', 'slap house']"
#  "['dance pop', 'edm', 'pop', 'pop dance', 'tropical house', 'uk dance']"
#  "['melanesian pop', 'pacific islands pop', 'png pop']"
#  "['canadian hip hop', 'canadian trap', 'pop rap', 'rap', 'southern hip hop', 'trap', 'trap soul', 'underground hip hop']"
#  "['dutch pop']" "['german hip hop']"
#  "['latin', 'latin pop', 'rap latina', 'reggaeton', 'trap latino']"
#  "['afrofuturism', 'dance pop', 'electropop', 'pop', 'pop rap', 'post-teen pop']"
#  "['uk hip hop']"
#  "['alt z', 'dance pop', 'electropop', 'pop', 'post-teen pop']"
#  "['modern rock', 'pop', 'rock']" "['pop rap', 'rap', 'trap']"
#  "['melodic rap', 'pop rap', 'rap', 'slap house', 'trap']"
#  "['dance pop', 'latin', 'latin pop', 'latin viral pop', 'pop', 'rap latina', 'reggaeton', 'trap latino']"
#  "['chill r&b', 'nyc pop']"
#  "['dance pop', 'edm', 'electro house', 'house', 'pop', 'progressive house', 'uk dance']"
#  "['sertanejo', 'sertanejo pop', 'sertanejo universitario']"
#  "['canadian pop', 'dance pop', 'pop', 'post-teen pop', 'viral pop']"
#  "['latin pop']" "['north carolina hip hop', 'rap']"
#  "['alt z', 'bedroom pop', 'electropop', 'indie pop', 'pop', 'post-teen pop']"
#  "['alt z', 'dance pop', 'pop', 'post-teen pop']"
#  "['dance pop', 'edm', 'pop', 'pop dance']"
#  "['folk-pop', 'modern rock', 'pop', 'pop rock']"
#  "['grunge', 'permanent wave', 'rock']" "['melodic rap', 'rap', 'trap']"
#  "['pop soul']" "['irish singer-songwriter', 'modern rock', 'pop']"
#  "['modern rock', 'uk pop']" "['sertanejo', 'sertanejo universitario']"
#  "['dance pop', 'pop', 'pop rap', 'rap']"
#  "['classic rock', 'glam rock', 'rock']" "['trap latino']"
#  "['dance pop', 'edm', 'pop dance', 'pop house', 'tropical house']"
#  "['edm', 'new french touch', 'pop dance', 'tropical house']"
#  "['colombian pop', 'reggaeton colombiano']"
#  "['plugg', 'vapor trap', 'viral rap']" "['permanent wave', 'pop']"
#  "['forro', 'sertanejo pop']" "['brooklyn drill']"
#  "['art pop', 'norwegian pop']" "['chicago rap', 'melodic rap']"
#  "['brooklyn drill', 'melodic rap', 'nyc rap']"
#  "['dance rock', 'modern rock', 'permanent wave', 'rock']"
#  "['album rock', 'art rock', 'classic rock', 'mellow gold', 'new wave', 'permanent wave', 'rock', 'soft rock']"
#  "['album rock', 'classic rock', 'mellow gold', 'rock', 'soft rock', 'yacht rock']"
#  "['pop', 'post-teen pop', 'talent show', 'uk pop']"
#  "['dance pop', 'pop', 'pop rap', 'post-teen pop', 'r&b', 'urban contemporary']"
#  "['sad rap']"
#  "['dance pop', 'pop', 'pop dance', 'post-teen pop', 'tropical house', 'uk pop']"
#  "['contemporary country', 'country', 'country road', 'modern country rock']"
#  "['neo soul', 'pop', 'pop soul', 'r&b', 'urban contemporary']"
#  "['cali rap', 'dance pop', 'pop', 'pop rap', 'trap queen']"
#  "['pop', 'pop rap', 'r&b']" "['funk bh', 'funk carioca']"
#  "['dance pop', 'edm', 'german dance', 'pop dance', 'pop edm', 'tropical house']"
#  "['funk carioca', 'pop nacional']"
#  "['detroit hip hop', 'hip hop', 'rap']" "['hip hop', 'rap']"
#  "['german alternative rap', 'german drill', 'german hip hop', 'german trap']"
#  "['london rap']" "['italian hip hop', 'italian pop']"
#  "['dance pop', 'edm', 'pop dance', 'pop edm', 'slap house', 'tropical house']"
#  "['neo mellow', 'pop rock', 'singer-songwriter']"
#  "['funk carioca', 'funk ostentacao', 'funk paulista']"
#  "['hip hop', 'pop rap', 'queens hip hop', 'rap', 'sudanese pop', 'underground hip hop']"
#  "['k-pop', 'k-pop girl group']"
#  "['escape room', 'r&b', 'rap latina', 'trap queen']"
#  "['contemporary country', 'country road']"
#  "['latin', 'reggaeton', 'reggaeton flow', 'trap latino']"
#  "['funk carioca', 'funk paulista', 'rave funk']"
#  "['dance pop', 'edm', 'electropop', 'pop', 'pop dance', 'tropical house']"
#  "['beatlesque', 'britpop', 'madchester', 'permanent wave', 'rock']"
#  "['dmv rap', 'pop', 'r&b', 'rap']" "['eau claire indie', 'folktronica']"
#  "['hip hop', 'miami hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap']"
#  "['art pop', 'dance pop', 'electropop', 'metropopolis', 'nz pop', 'pop', 'post-teen pop']"
#  "['frauenrap', 'german hip hop', 'german pop']" "['nyc rap']"
#  "['dance pop', 'pop rap']"
#  "['garage rock', 'permanent wave', 'rock', 'sheffield indie']"
#  "['atl hip hop', 'pop rap', 'rap', 'trap']"
#  "['italian adult pop', 'italian pop']" "['nz pop']" "['reggaeton']"
#  "['francoton', 'french hip hop', 'pop urbaine', 'rap francais', 'rap marseille']"
#  "['conscious hip hop', 'hip hop', 'north carolina hip hop', 'rap']"
#  "['emo rap', 'miami hip hop']"
#  "['modern rock', 'pop rap', 'seattle hip hop']"
#  "['ohio hip hop', 'pop rap']"
#  "['dance pop', 'dutch edm', 'edm', 'pop', 'pop dance', 'progressive house', 'tropical house']"
#  "['dembow', 'dominican pop', 'rap dominicano', 'trap latino']"
#  "['alternative metal', 'nu metal', 'post-grunge', 'rap metal']"
#  "['dance pop', 'pop', 'pop rap']" "['funk 150 bpm', 'funk carioca']"
#  "['atl hip hop', 'atl trap', 'rap', 'trap']" "['rap', 'trap']"
#  "['colombian pop', 'latin', 'reggaeton', 'reggaeton colombiano', 'trap latino']"
#  "['electropop', 'escape room', 'pop']"
#  "['electro house', 'pop nacional', 'slap house']"
#  "['melodic rap', 'rap', 'rap conscient', 'trap', 'vapor trap']"
#  "['australian pop']" "['funk carioca', 'funk ostentacao']"
#  "['eurovision', 'nouvelle chanson francaise']" "['modern rock', 'rock']"
#  "['dance pop', 'hip pop', 'pop', 'pop rap', 'post-teen pop', 'queens hip hop']"
#  "['eurovision', 'oulu metal', 'trancecore']" "['eurovision']"
#  "['k-pop girl group']" "['boston hip hop', 'hip hop', 'pop rap', 'rap']"
#  "['bubblegrunge', 'chicago indie', 'indie pop', 'pop']" "['dream smp']"
#  "['icelandic pop', 'sunnlensk tonlist']"
#  "['dance pop', 'electropop', 'metropopolis', 'pop', 'post-teen pop', 'uk alternative pop']"
#  "['reggaeton', 'reggaeton flow', 'trap latino']"
#  "['alt z', 'canadian contemporary r&b', 'indie cafe pop', 'pop', 'pop rock', 'post-teen pop']"
#  "['bedroom soul', 'pop']"
#  "['atl hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap']"
#  "['german hip hop', 'hamburg hip hop']" "['forro']" "['weirdcore']"
#  "['hip hop', 'rap', 'trap', 'underground hip hop']"
#  "['funk carioca', 'funk pop', 'pagode baiano', 'pop nacional']"
#  "['memphis hip hop', 'rap', 'southern hip hop', 'tennessee hip hop', 'trap']"
#  "['alternative r&b', 'dance pop', 'pop', 'r&b']" "['bedroom pop']"
#  "['alt z', 'indie cafe pop', 'pop', 'uk pop']"
#  "['electropop', 'pop', 'pop rap']" "['forro', 'piseiro']"
#  "['east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'pop rap', 'rap']"
#  "['argentine hip hop', 'trap argentino', 'trap latino', 'trap triste']"
#  "['alt z', 'australian pop', 'dance pop', 'indie cafe pop', 'pop', 'post-teen pop', 'uk pop']"
#  "['latin', 'latin hip hop', 'reggaeton', 'reggaeton colombiano', 'reggaeton flow', 'trap latino']"
#  "['dance pop', 'pop', 'pop rap', 'post-teen pop']"
#  "['indie pop', 'vancouver indie']" "['piseiro']"
#  "['trap argentino', 'trap latino', 'trap triste']"
#  "['deep underground hip hop', 'kentucky hip hop', 'pop rap', 'rap']"
#  "['new romantic', 'new wave', 'new wave pop', 'permanent wave', 'soft rock', 'synthpop']"
#  "['latin', 'puerto rican pop', 'reggaeton', 'trap latino']"
#  "['german pop']" "['sertanejo pop']" "['art pop', 'pop']"
#  "['edm', 'electronic trap']"
#  "['dance pop', 'edm', 'electronic trap', 'pop', 'pop dance']"
#  "['australian dance', 'australian pop', 'dance pop', 'pop']"
#  "['dance pop', 'deep euro house', 'deep house', 'edm', 'german dance', 'pop', 'pop dance', 'tropical house']"
#  "['australian psych', 'neo-psychedelic']"
#  "['indie cafe pop', 'indie poptimism', 'modern rock', 'pop', 'pop rock']"
#  "['indonesian pop']" "['hip hop', 'pop rap', 'rap']"
#  "['italian adult pop', 'italian indie pop', 'italian pop', 'italian pop rock']"
#  "['latin', 'reggaeton', 'reggaeton flow', 'trap boricua', 'trap latino']"
#  "['french hip hop', 'old school rap francais', 'pop urbaine', 'rap conscient']"
#  "['latin pop', 'viral pop']" "['emo rap', 'lgbtq+ hip hop']"
#  "['urbano espanol']" "['pop rap', 'rhode island rap']"
#  "['dance pop', 'electropop', 'etherpop', 'indie poptimism', 'pop', 'post-teen pop']"
#  "['bedroom pop', 'indie pop', 'pop']" "['german hip hop', 'german pop']"
#  "['alt z', 'dance pop', 'electropop', 'pop', 'post-teen pop', 'viral pop']"
#  "['alt z', 'indie cafe pop', 'modern indie pop', 'pop', 'social media pop']"
#  "['tropical house']"
#  "['melodic metalcore', 'metalcore', 'rock', 'uk metalcore']"
#  "['brazilian hip hop', 'funk ostentacao']"
#  "['australian pop', 'indie cafe pop', 'pop', 'pop rock', 'post-teen pop']"
#  "['cubaton', 'dominican pop', 'pop venezolano', 'reggaeton', 'reggaeton flow', 'trap latino']"
#  "['german alternative rap', 'german hip hop', 'german trap', 'tekk']"
#  "['dance pop', 'pop', 'post-teen pop', 'uk pop']"
#  "['contemporary country']" "['cumbia pop']"
#  "['dance pop', 'pop', 'pop rap', 'r&b', 'rap']" "['trap queen']"
#  "['hip hop', 'ohio hip hop', 'pop rap', 'rap']"
#  "['dream smp', 'viral rap']"
#  "['dance pop', 'pop', 'r&b', 'urban contemporary']"
#  "['disco', 'europop', 'new romantic', 'new wave', 'new wave pop', 'soft rock', 'synthpop']"
#  "['adult standards', 'brill building pop', 'easy listening', 'lounge', 'rockabilly', 'vocal jazz']"
#  "['adult standards', 'canadian pop', 'jazz pop', 'lounge']"
#  "['adult standards', 'brill building pop', 'easy listening', 'lounge', 'mellow gold', 'vocal jazz']"
#  "['dance pop', 'neo mellow', 'pop', 'pop rock', 'post-teen pop', 'talent show']"
#  "['latin pop', 'puerto rican pop']"
#  "['adult standards', 'easy listening', 'lounge', 'vocal jazz']"
#  "['adult standards', 'easy listening', 'lounge']" "['musical advocacy']"
#  "['album rock', 'art rock', 'beatlesque', 'classic rock', 'mellow gold', 'rock', 'soft rock']"
#  "['album rock', 'art rock', 'beatlesque', 'classic rock', 'folk rock', 'mellow gold', 'rock']"
#  "['adult standards', 'lounge', 'soul', 'vocal jazz']"
#  "['adult standards', 'easy listening', 'lounge', 'swing', 'vocal jazz']"
#  "['atl hip hop', 'plugg', 'rap', 'trap']"
#  "['adult standards', 'american folk revival']"
#  "['celtic', 'celtic punk', 'celtic rock', 'folk punk', 'irish folk', 'punk']"
#  "['classic uk pop', 'new wave pop', 'rock-and-roll', 'rockabilly', 'soft rock']"
#  "['rock-and-roll', 'rockabilly']"
#  "['australian dance', 'australian pop', 'dance pop', 'electropop', 'eurodance', 'europop', 'new wave pop', 'pop']"
#  "['adult standards', 'brill building pop', 'easy listening', 'lounge', 'vocal jazz']"
#  "['glam rock', 'mellow gold', 'piano rock']"
#  "['forro', 'sertanejo', 'sertanejo pop', 'sertanejo universitario']"
#  "['boy band', 'dance pop', 'pop', 'post-teen pop']"
#  "['dance pop', 'hip pop', 'pop', 'post-teen pop', 'urban contemporary']"
#  "['hollywood', 'show tunes']" "['motown', 'soul']"
#  "['adult standards', 'lounge', 'torch song', 'vocal jazz']"
#  "['soundtrack']"
#  "['classic rock', 'heartland rock', 'mellow gold', 'permanent wave', 'rock', 'singer-songwriter']"
#  "['british soul', 'dance pop', 'europop', 'pop', 'post-teen pop', 'talent show']"
#  "['dance pop', 'hip pop', 'pop', 'post-teen pop']" "['a cappella']"
#  "['chicago soul', 'classic soul', 'funk', 'motown', 'neo soul', 'quiet storm', 'soul', 'southern soul']"
#  "['album rock', 'classic rock', 'country rock', 'folk rock', 'heartland rock', 'mellow gold', 'rock', 'soft rock', 'yacht rock']"
#  "['canadian hip hop', 'canadian trap', 'melodic rap', 'pop rap', 'r&b', 'rap', 'toronto rap', 'trap']"
#  "['alt z', 'modern indie pop', 'social media pop']"
#  "['italian hip hop', 'italian pop', 'trap italiana']"
#  "['dance pop', 'edm', 'pop', 'pop dance', 'post-teen pop', 'tropical house', 'uk dance', 'uk funky']"
#  "['mariachi', 'nuevo regional mexicano', 'ranchera', 'regional mexican']"
#  "['south african house']" "['basshall', 'francoton']"
#  "['atl hip hop', 'hip hop', 'rap', 'trap']"
#  "['indie pop', 'modern rock', 'pop', 'rock']"
#  "['contemporary country', 'country', 'pop']" "['pop r&b', 'r&b']"
#  "['melodic rap']"
#  "['afroswing', 'london rap', 'uk alternative hip hop', 'uk hip hop']"
#  "['hip hop', 'pop', 'pop rap', 'r&b', 'southern hip hop', 'trap', 'trap soul']"
#  "['dance pop', 'girl group', 'pop', 'post-teen pop', 'talent show', 'uk pop']"
#  "['dance pop', 'electropop', 'pop', 'pop rap', 'post-teen pop', 'viral pop']"
#  "['canadian latin', 'canadian pop', 'dance pop', 'pop', 'pop rap']"
#  "['indie poptimism', 'pop']" "['alternative r&b', 'viral pop']"
#  "['champeta', 'colombian pop', 'electro latino', 'latin', 'latin pop', 'reggaeton', 'reggaeton colombiano', 'trap latino']"
#  "['pop', 'r&b', 'soul']" "['australian rock', 'hard rock', 'rock']"
#  "['memphis hip hop', 'rap', 'southern hip hop', 'trap']"
#  "['detroit hip hop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap']"
#  "['pop rap']" "['argentine hip hop', 'trap argentino', 'trap latino']"
#  "['folk-pop', 'neo mellow', 'pop', 'pop rock']"
#  "['alt z', 'electropop', 'modern rock', 'pop']"
#  "['edm', 'pop', 'pop dance', 'tropical house']"
#  "['british soul', 'pop', 'pop soul', 'uk pop']"
#  "['canadian hip hop', 'pop']"
#  "['hip hop', 'indie pop rap', 'oakland hip hop', 'pop rap', 'rap']"
#  "['french hip hop', 'pop urbaine', 'rap francais', 'rap marseille']"
#  "['r&b en espanol']"
#  "['atl hip hop', 'hip hop', 'melodic rap', 'rap', 'trap']"
#  "['alt z', 'nz pop', 'pop']" "['funk carioca']"
#  "['colombian pop', 'latin', 'pop reggaeton', 'reggaeton', 'reggaeton colombiano', 'trap latino']"
#  "['kentucky hip hop', 'pop', 'pop rap', 'r&b', 'rap', 'trap']"
#  "['viral rap']"
#  "['alt z', 'dance pop', 'electropop', 'indie cafe pop', 'indie poptimism', 'modern rock', 'pop', 'pop rap', 'post-teen pop', 'talent show']"
#  "['trap chileno', 'trap latino']"
#  "['conscious hip hop', 'hip hop', 'rap', 'west coast rap']"
#  "['disco', 'funk', 'jazz funk', 'motown', 'quiet storm', 'soul']"
#  "['belgian hip hop', 'french hip hop', 'pop urbaine', 'rap belge', 'rap conscient']"
#  "['emo rap', 'rap']"
#  "['r&b brasileiro', 'rap cearense', 'trap brasileiro']"
#  "['scandipop', 'swedish pop']"
#  "['dance pop', 'pop', 'post-teen pop', 'r&b']"
#  "['funk carioca', 'funk pop']"
#  "['alternative r&b', 'chill r&b', 'indie r&b', 'pop']"
#  "['german hip hop', 'german pop', 'hamburg hip hop']" "['jawaiian']"
#  "['dmv rap', 'hip hop', 'pop rap', 'rap', 'trap', 'underground hip hop', 'vapor trap']"
#  "['latin', 'latin hip hop', 'reggaeton', 'reggaeton flow', 'trap latino']"
#  "['florida rap']"
#  "['cali rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap']"
#  "['acoustic pop', 'neo mellow', 'pop', 'pop rock']"
#  "['boy band', 'dance pop', 'electropop', 'pop', 'post-teen pop']"
#  "['afroswing', 'social media pop']"
#  "['edm', 'pop dance', 'pop edm', 'tropical house']"
#  "['dominican pop', 'pop reggaeton', 'urbano espanol']"
#  "['dance pop', 'german dance', 'pop dance', 'slap house', 'tropical house']"
#  "['hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap', 'underground hip hop']"
#  "['memphis hip hop']"
#  "['dembow', 'latin', 'rap dominicano', 'reggaeton', 'trap latino']"
#  "['boy band', 'pop', 'post-teen pop', 'talent show']"
#  "['german cloud rap', 'german hip hop']"
#  "['conscious hip hop', 'dmv rap', 'hip hop', 'pop rap', 'rap']"
#  "['alternative r&b', 'melodic rap', 'pop rap']"
#  "['german drill', 'german hip hop']"
#  "['latin', 'r&b en espanol', 'reggaeton', 'trap latino']"
#  "['latin', 'perreo', 'reggaeton', 'reggaeton flow', 'trap latino']"
#  "['christlicher rap', 'german hip hop']" "['chicago rap', 'rap']"
#  "['k-pop']" "['cali rap', 'melodic rap', 'pop rap', 'rap', 'trap']"
#  "['melodic rap', 'pop rap']"
#  "['album rock', 'classic rock', 'hard rock', 'mellow gold', 'rock', 'soft rock']"
#  "['melodic rap', 'philly rap', 'rap', 'trap']" "['modern rock']"
#  "['dance pop', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap']"
#  "['melodic rap', 'pop rap', 'rap', 'trap']"
#  "['francoton', 'french hip hop', 'pop urbaine', 'rap francais']"
#  "['alt z', 'indie cafe pop', 'pop', 'post-teen pop', 'social media pop']"
#  "['indie rockism']" "['italian hip hop']"
#  "['canadian hip hop', 'canadian trap', 'hip hop', 'melodic rap', 'pop rap', 'rap', 'toronto rap', 'trap']"
#  "['alt z', 'electropop', 'pop']"
#  "['pop', 'pop rap', 'r&b', 'rap', 'toronto rap', 'trap', 'urban contemporary']"
#  "['atl hip hop', 'hip hop', 'pop rap', 'rap']" "['melodic rap', 'trap']"
#  "['german hip hop', 'german trap', 'german underground rap', 'hamburg hip hop']"
#  "['atl hip hop', 'hip hop', 'melodic rap', 'rap', 'trap', 'underground hip hop', 'viral rap']"
#  "['k-rap']"
#  "['edm', 'electro house', 'pop dance', 'pop edm', 'progressive electro house', 'tropical house']"
#  "['chicago drill', 'chicago rap', 'drill', 'rap', 'southern hip hop', 'trap']"
#  "['banda', 'corrido', 'norteno', 'regional mexican']"
#  "['alt z', 'electropop', 'indie pop', 'pop', 'post-teen pop']"
#  "['dance pop', 'pop', 'pop rap', 'post-teen pop', 'r&b']"
#  "['boy band', 'hip hop', 'rap']"
#  "['colombian pop', 'dance pop', 'latin', 'latin pop', 'pop']"
#  "['modern alternative rock', 'modern rock', 'pop', 'rock']"
#  "['electro house']"
#  "['dance pop', 'edm', 'electropop', 'indietronica', 'metropopolis', 'pop', 'post-teen pop', 'uk pop']"
#  "['alternative pop rock', 'pop']"
#  "['latin', 'latin pop', 'reggaeton', 'reggaeton flow', 'trap latino']"
#  "['modern indie pop']"
#  "['dance pop', 'escape room', 'minnesota hip hop', 'pop', 'pop rap', 'post-teen pop', 'trap queen']"
#  "['italian hip hop', 'trap italiana']"
#  "['albanian hip hop', 'german hip hop']"
#  "['alternative r&b', 'dance pop', 'pop', 'pop rap', 'r&b', 'urban contemporary']"
#  "['french hip hop', 'pop urbaine', 'rap francais']"
#  "['latin', 'latin hip hop', 'latin pop', 'pop reggaeton', 'reggaeton', 'reggaeton flow', 'trap latino']"
#  "['sertanejo pop', 'sertanejo universitario']" "['venezuelan hip hop']"
#  "['meme rap', 'sad rap', 'vapor trap', 'viral rap']"
#  "['grime', 'uk hip hop']" "['brega funk', 'funk carioca']"
#  "['atl hip hop', 'hip hop', 'melodic rap', 'pop r&b', 'pop rap', 'r&b', 'rap', 'southern hip hop', 'trap']"
#  "['dance pop', 'edm', 'electro house', 'moombahton', 'pop', 'pop dance', 'pop rap']"
#  "['hip hop', 'pittsburgh rap', 'rap']" "['chill r&b', 'pop']"
#  "['hip hop', 'new orleans rap', 'pop rap', 'rap', 'trap']"
#  "['colombian pop', 'latin', 'latin pop', 'reggaeton', 'reggaeton colombiano', 'trap latino']"
#  "['new wave pop']"
#  "['hip hop', 'philly rap', 'pop rap', 'rap', 'southern hip hop', 'trap']"
#  "['atl hip hop', 'atl trap', 'gangster rap', 'hip hop', 'melodic rap', 'pop rap', 'rap', 'trap']"
#  "['deep german hip hop', 'german hip hop', 'hamburg hip hop']"
#  "['basshall', 'turkish trap']"
#  "['dance pop', 'edm', 'electro house', 'pop', 'pop dance', 'pop edm', 'tropical house']"
#  "['dance pop', 'edm', 'pop', 'pop dance', 'post-teen pop', 'tropical house', 'uk pop']"
#  "['latin', 'latin pop', 'puerto rican pop']"
#  "['gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap']"]
# ************
# ['B' 'C#/Db' 'A' 'D#/Eb' 'G#/Ab' 'F#/Gb' 'C' 'D' 'A#/Bb' 'G' 'E' 'F' ' ']

# %%
data['Release Date']=pd.to_datetime(data['Release Date'],infer_datetime_format=True,errors='coerce')
data['month']=data['Release Date'].dt.month

data=data.drop('Release Date',axis=1)
data.head()
# Out:
#    Highest Charting Position  Number of Times Charted          Artist  \
# 0                          1                        8        Måneskin
# 1                          2                        3   The Kid LAROI
# 2                          1                       11  Olivia Rodrigo
# 3                          3                        5      Ed Sheeran
# 4                          5                        1       Lil Nas X
#
#   Artist Followers                                   Genre Popularity  \
# 0          3377762  ['indie rock italiano', 'italian pop']        100
# 1          2230022                  ['australian hip hop']         99
# 2          6266514                                 ['pop']         99
# 3         83293380                       ['pop', 'uk pop']         98
# 4          5473565           ['lgbtq+ hip hop', 'pop rap']         96
#
#   Danceability Energy Loudness Speechiness Acousticness Liveness    Tempo  \
# 0        0.714    0.8   -4.808      0.0504        0.127    0.359  134.002
# 1        0.591  0.764   -5.484      0.0483       0.0383    0.103  169.928
# 2        0.563  0.664   -5.044       0.154        0.335   0.0849  166.928
# 3        0.808  0.897   -3.712      0.0348       0.0469    0.364  126.026
# 4        0.736  0.704   -7.409      0.0615       0.0203   0.0501  149.995
#
#   Duration (ms) Valence  Chord  month
# 0        211560   0.589      B   12.0
# 1        141806   0.478  C#/Db    7.0
# 2        178147   0.688      A    5.0
# 3        231041   0.591      B    6.0
# 4        212000   0.894  D#/Eb    7.0

# %%
data.dtypes
# Out:
# Highest Charting Position      int64
# Number of Times Charted        int64
# Artist                        object
# Artist Followers              object
# Genre                         object
# Popularity                    object
# Danceability                  object
# Energy                        object
# Loudness                      object
# Speechiness                   object
# Acousticness                  object
# Liveness                      object
# Tempo                         object
# Duration (ms)                 object
# Valence                       object
# Chord                         object
# month                        float64
# dtype: object

# %%
data['Artist Followers'][0]
# Out:
# '3377762'

# %%
#converting object to float

# %%
#to_numeric  --to convert to numeric form or float
#errors='coerce'--to convert non numerical values to nan values
data['Artist Followers']=pd.to_numeric(data['Artist Followers'],errors='coerce')
data['Popularity']=pd.to_numeric(data['Popularity'],errors='coerce')
data['Danceability']=pd.to_numeric(data['Danceability'],errors='coerce')
data['Energy']=pd.to_numeric(data['Energy'],errors='coerce')
data['Loudness']=pd.to_numeric(data['Loudness'],errors='coerce')
data['Speechiness']=pd.to_numeric(data['Speechiness'],errors='coerce')
data['Acousticness']=pd.to_numeric(data['Acousticness'],errors='coerce')
data['Liveness']=pd.to_numeric(data['Liveness'],errors='coerce')
data['Tempo']=pd.to_numeric(data['Tempo'],errors='coerce')
data['Duration (ms)']=pd.to_numeric(data['Duration (ms)'],errors='coerce')
data['Valence']=pd.to_numeric(data['Valence'],errors='coerce')

# %%
data.dtypes
# Out:
# Highest Charting Position      int64
# Number of Times Charted        int64
# Artist                        object
# Artist Followers             float64
# Genre                         object
# Popularity                   float64
# Danceability                 float64
# Energy                       float64
# Loudness                     float64
# Speechiness                  float64
# Acousticness                 float64
# Liveness                     float64
# Tempo                        float64
# Duration (ms)                float64
# Valence                      float64
# Chord                         object
# month                        float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Highest Charting Position     0
# Number of Times Charted       0
# Artist                        0
# Artist Followers             11
# Genre                         0
# Popularity                   11
# Danceability                 11
# Energy                       11
# Loudness                     11
# Speechiness                  11
# Acousticness                 11
# Liveness                     11
# Tempo                        11
# Duration (ms)                11
# Valence                      11
# Chord                         0
# month                        11
# dtype: int64

# %%
#filling nan values

# %%
# to do? display the nan values

# %%
data=data.dropna()
data
# Out:
#       Highest Charting Position  Number of Times Charted  \
# 0                             1                        8
# 1                             2                        3
# 2                             1                       11
# 3                             3                        5
# 4                             5                        1
# ...                         ...                      ...
# 1551                        195                        1
# 1552                        196                        1
# 1553                        197                        1
# 1554                        198                        1
# 1555                        199                        1
#
#                              Artist  Artist Followers  \
# 0                          Måneskin         3377762.0
# 1                     The Kid LAROI         2230022.0
# 2                    Olivia Rodrigo         6266514.0
# 3                        Ed Sheeran        83293380.0
# 4                         Lil Nas X         5473565.0
# ...                             ...               ...
# 1551                       Dua Lipa        27167675.0
# 1552                 Jorge & Mateus        15019109.0
# 1553                 Camila Cabello        22698747.0
# 1554  Dadá Boladão, Tati Zaqui, OIK          208630.0
# 1555                   Taylor Swift        42227614.0
#
#                                                   Genre  Popularity  \
# 0                ['indie rock italiano', 'italian pop']       100.0
# 1                                ['australian hip hop']        99.0
# 2                                               ['pop']        99.0
# 3                                     ['pop', 'uk pop']        98.0
# 4                         ['lgbtq+ hip hop', 'pop rap']        96.0
# ...                                                 ...         ...
# 1551                     ['dance pop', 'pop', 'uk pop']        79.0
# 1552           ['sertanejo', 'sertanejo universitario']        66.0
# 1553  ['dance pop', 'electropop', 'pop', 'post-teen ...        81.0
# 1554                     ['brega funk', 'funk carioca']        60.0
# 1555                           ['pop', 'post-teen pop']        70.0
#
#       Danceability  Energy  Loudness  Speechiness  Acousticness  Liveness  \
# 0            0.714   0.800    -4.808       0.0504       0.12700    0.3590
# 1            0.591   0.764    -5.484       0.0483       0.03830    0.1030
# 2            0.563   0.664    -5.044       0.1540       0.33500    0.0849
# 3            0.808   0.897    -3.712       0.0348       0.04690    0.3640
# 4            0.736   0.704    -7.409       0.0615       0.02030    0.0501
# ...            ...     ...       ...          ...           ...       ...
# 1551         0.762   0.700    -6.021       0.0694       0.00261    0.1530
# 1552         0.528   0.870    -3.123       0.0851       0.24000    0.3330
# 1553         0.765   0.523    -4.333       0.0300       0.18400    0.1320
# 1554         0.832   0.550    -7.026       0.0587       0.24900    0.1820
# 1555         0.448   0.603    -7.176       0.0640       0.43300    0.0862
#
#         Tempo  Duration (ms)  Valence  Chord  month
# 0     134.002       211560.0    0.589      B   12.0
# 1     169.928       141806.0    0.478  C#/Db    7.0
# 2     166.928       178147.0    0.688      A    5.0
# 3     126.026       231041.0    0.591      B    6.0
# 4     149.995       212000.0    0.894  D#/Eb    7.0
# ...       ...            ...      ...    ...    ...
# 1551  116.073       209320.0    0.608      A    6.0
# 1552  152.370       181930.0    0.714      B   10.0
# 1553  104.988       217307.0    0.394      D    1.0
# 1554  154.064       152784.0    0.881      F    9.0
# 1555  205.272       221307.0    0.422      G   11.0
#
# [1545 rows x 17 columns]

# %% [raw]
# data['Artist Followers']=data['Artist Followers'].fillna(data['Artist Followers'].mean)
# data['Popularity']=data['Popularity'].fillna(data['Popularity'].mean)

# %% [raw]
# scaler =StandardScaler()
#
# data['Artist'] =scaler.fit_transform(data[['Artist']])
# data['Artist Followers'] =scaler.fit_transform(data[['Artist Followers']])
# data['Genre'] =scaler.fit_transform(data[['Genre']])
# data['Popularity'] =scaler.fit_transform(data[['Popularity']])
# data['Danceability'] =scaler.fit_transform(data[['Danceability']])
# data['Energy'] =scaler.fit_transform(data[['Energy']])
# data['Loudness'] =scaler.fit_transform(data[['Loudness']])
# data['Speechiness'] =scaler.fit_transform(data[['Speechiness']])
# data['Acousticness'] =scaler.fit_transform(data[['Acousticness']])
# data['Liveness'] =scaler.fit_transform(data[['Liveness']])
# data['Tempo'] =scaler.fit_transform(data[['Tempo']])
# data['Duration (ms)'] =scaler.fit_transform(data[['Duration (ms)']])
# data['Valence'] =scaler.fit_transform(data[['Valence']])
# data['Chord'] =scaler.fit_transform(data[['Chord']])
# data['month'] =scaler.fit_transform(data[['month']])
#
# data.head()

# %%
scaler =MinMaxScaler()

#data['Artist'] =scaler.fit_transform(data[['Artist']])
data['Artist Followers'] =scaler.fit_transform(data[['Artist Followers']])
#data['Genre'] =scaler.fit_transform(data[['Genre']])
data['Popularity'] =scaler.fit_transform(data[['Popularity']])
data['Danceability'] =scaler.fit_transform(data[['Danceability']])
data['Energy'] =scaler.fit_transform(data[['Energy']])
data['Loudness'] =scaler.fit_transform(data[['Loudness']])
data['Speechiness'] =scaler.fit_transform(data[['Speechiness']])
data['Acousticness'] =scaler.fit_transform(data[['Acousticness']])
data['Liveness'] =scaler.fit_transform(data[['Liveness']])
data['Tempo'] =scaler.fit_transform(data[['Tempo']])
data['Duration (ms)'] =scaler.fit_transform(data[['Duration (ms)']])
data['Valence'] =scaler.fit_transform(data[['Valence']])
#data['Chord'] =scaler.fit_transform(data[['Chord']])
#data['month'] =scaler.fit_transform(data[['month']])

data.head()
# Out:
#    Highest Charting Position  Number of Times Charted          Artist  \
# 0                          1                        8        Måneskin
# 1                          2                        3   The Kid LAROI
# 2                          1                       11  Olivia Rodrigo
# 3                          3                        5      Ed Sheeran
# 4                          5                        1       Lil Nas X
#
#    Artist Followers                                   Genre  Popularity  \
# 0          0.040475  ['indie rock italiano', 'italian pop']        1.00
# 1          0.026702                  ['australian hip hop']        0.99
# 2          0.075140                                 ['pop']        0.99
# 3          0.999467                       ['pop', 'uk pop']        0.98
# 4          0.065625           ['lgbtq+ hip hop', 'pop rap']        0.96
#
#    Danceability    Energy  Loudness  Speechiness  Acousticness  Liveness  \
# 0      0.679518  0.814410  0.763187     0.031599      0.127744  0.360076
# 1      0.531325  0.775109  0.737844     0.029159      0.038507  0.088401
# 2      0.497590  0.665939  0.754339     0.151952      0.337005  0.069192
# 3      0.792771  0.920306  0.804274     0.013476      0.047159  0.365383
# 4      0.706024  0.709607  0.665679     0.044493      0.020397  0.032261
#
#       Tempo  Duration (ms)   Valence  Chord  month
# 0  0.550500       0.325134  0.588173      B   12.0
# 1  0.777085       0.200129  0.470961  C#/Db    7.0
# 2  0.758164       0.265255  0.692714      A    5.0
# 3  0.500196       0.360046  0.590285      B    6.0
# 4  0.651368       0.325923  0.910243  D#/Eb    7.0

# %%
 le =LabelEncoder()
    
data['Artist'] =le.fit_transform(data['Artist'])
data['Genre'] =le.fit_transform(data['Genre'])  
data['Chord'] =le.fit_transform(data['Chord'])

data.head()
# Out:
#    Highest Charting Position  Number of Times Charted  Artist  \
# 0                          1                        8     469
# 1                          2                        3     643
# 2                          1                       11     500
# 3                          3                        5     203
# 4                          5                        1     381
#
#    Artist Followers  Genre  Popularity  Danceability    Energy  Loudness  \
# 0          0.040475    276        1.00      0.679518  0.814410  0.763187
# 1          0.026702     63        0.99      0.531325  0.775109  0.737844
# 2          0.075140    364        0.99      0.497590  0.665939  0.754339
# 3          0.999467    363        0.98      0.792771  0.920306  0.804274
# 4          0.065625    312        0.96      0.706024  0.709607  0.665679
#
#    Speechiness  Acousticness  Liveness     Tempo  Duration (ms)   Valence  \
# 0     0.031599      0.127744  0.360076  0.550500       0.325134  0.588173
# 1     0.029159      0.038507  0.088401  0.777085       0.200129  0.470961
# 2     0.151952      0.337005  0.069192  0.758164       0.265255  0.692714
# 3     0.013476      0.047159  0.365383  0.500196       0.360046  0.590285
# 4     0.044493      0.020397  0.032261  0.651368       0.325923  0.910243
#
#    Chord  month
# 0      2   12.0
# 1      4    7.0
# 2      0    5.0
# 3      2    6.0
# 4      6    7.0

# %% [markdown]
# # ploting

# %%
sort=data.sort_values(by=['Artist Followers'],ascending=False)
plt.figure(figsize=[10,8])
plt.title('Top in Artist Followers')
sns.barplot(x='Popularity',y='Artist Followers',data=sort.head(10))
# Out:
# <AxesSubplot:title={'center':'Top in Artist Followers'}, xlabel='Popularity', ylabel='Artist Followers'>

# %%
sort=data.sort_values(by=['Danceability'],ascending=False)
plt.figure(figsize=[10,8])
plt.title('Top in Danceability')
sns.barplot(x='Popularity',y='Danceability',data=sort.head(10))
# Out:
# <AxesSubplot:title={'center':'Top in Danceability'}, xlabel='Popularity', ylabel='Danceability'>

# %%
sort=data.sort_values(by=['Energy'],ascending=False)
plt.figure(figsize=[10,8])
plt.title('Top in Energy')
sns.barplot(x='Popularity',y='Energy',data=sort.head(10))
# Out:
# <AxesSubplot:title={'center':'Top in Energy'}, xlabel='Popularity', ylabel='Energy'>

# %%
sort=data.sort_values(by=['Loudness'],ascending=False)
plt.figure(figsize=[10,8])
plt.title('Top in Loudness')
sns.barplot(x='Popularity',y='Loudness',data=sort.head(10))
# Out:
# <AxesSubplot:title={'center':'Top in Loudness'}, xlabel='Popularity', ylabel='Loudness'>

# %%
sort=data.sort_values(by=['Chord'],ascending=False)
plt.figure(figsize=[10,8])
plt.title('Top in Chord')
sns.barplot(x='Popularity',y='Chord',data=sort.head(12))
# Out:
# <AxesSubplot:title={'center':'Top in Chord'}, xlabel='Popularity', ylabel='Chord'>

# %%
sort=data.sort_values(by=['month'],ascending=False)
plt.figure(figsize=[10,8])
plt.title('Top in month')
sns.barplot(x='Popularity',y='month',data=sort.head(12))
# Out:
# <AxesSubplot:title={'center':'Top in month'}, xlabel='Popularity', ylabel='month'>

# %%
plt.xlabel('Artist')
plt.ylabel('Popularity')
plt.scatter(data['Duration (ms)'],data['Popularity'])

# %% [markdown]
# # Correlation

# %%
c=data.corr()
plt.figure(figsize=[12,12])
sns.heatmap(c,annot=True)
# Out:
# <AxesSubplot:>

# %%
print(data['Artist'].corr(data['Popularity']))
print(data['Artist Followers'].corr(data['Popularity']))
print(data['Danceability'].corr(data['Popularity']))
print(data['Loudness'].corr(data['Popularity']))
print(data['Duration (ms)'].corr(data['Popularity']))

print(data['Chord'].corr(data['Popularity']))
print(data['Energy'].corr(data['Popularity']))

print(data['month'].corr(data['Popularity']))
# Out:
# 0.03732347786491108
# 0.10435772123165069
# 0.028434691817529237
# 0.1587674680318133
# 0.08209572542261855
# 0.04578761512655858
# 0.09469051758444466
# -0.06380392190329015

# %%
print(data['Liveness'].corr(data['Popularity']))
print(data['Speechiness'].corr(data['Popularity']))
print(data['Tempo'].corr(data['Popularity']))
print(data['Acousticness'].corr(data['Popularity']))
print(data['Valence'].corr(data['Popularity']))
print(data['Genre'].corr(data['Popularity']))
# Out:
# -0.029459634726915363
# -0.032090633591528
# -0.02495087653404515
# -0.09124461072497658
# -0.000953392411440151
# -0.10758887170189574

# %%
data =data.drop(['Artist','Chord','month'],axis=1)
data.head()
# Out:
#    Highest Charting Position  Number of Times Charted  Artist Followers  \
# 0                          1                        8          0.040475
# 1                          2                        3          0.026702
# 2                          1                       11          0.075140
# 3                          3                        5          0.999467
# 4                          5                        1          0.065625
#
#    Genre  Popularity  Danceability    Energy  Loudness  Speechiness  \
# 0    276        1.00      0.679518  0.814410  0.763187     0.031599
# 1     63        0.99      0.531325  0.775109  0.737844     0.029159
# 2    364        0.99      0.497590  0.665939  0.754339     0.151952
# 3    363        0.98      0.792771  0.920306  0.804274     0.013476
# 4    312        0.96      0.706024  0.709607  0.665679     0.044493
#
#    Acousticness  Liveness     Tempo  Duration (ms)   Valence
# 0      0.127744  0.360076  0.550500       0.325134  0.588173
# 1      0.038507  0.088401  0.777085       0.200129  0.470961
# 2      0.337005  0.069192  0.758164       0.265255  0.692714
# 3      0.047159  0.365383  0.500196       0.360046  0.590285
# 4      0.020397  0.032261  0.651368       0.325923  0.910243

# %%
x=data.drop('Popularity',axis=1)
y=data['Popularity']

# %%
model_params={'AdaBoostRegressor':{'model':AdaBoostRegressor(),'params':{}},
              'GradientBoostingRegressor':{'model':GradientBoostingRegressor(),'params':{}},
              'XGBRFRegressor':{'model':XGBRFRegressor(),'params':{}}}

# %%
scores = []
models = ['AdaBoostRegressor','GradientBoostingRegressor','XGBRFRegressor']
for model_name in models:
    mp=model_params[model_name]
    gds=GridSearchCV(mp['model'],mp['params'],cv=5,return_train_score=True)
    gds.fit(x,y)
    scores.append({'model':model_name, 'best_score':gds.best_score_ , 'best_params':gds.best_params_})

# %%
scores
# Out:
# [{'model': 'AdaBoostRegressor',
#   'best_score': 0.40037127993223776,
#   'best_params': {}},
#  {'model': 'GradientBoostingRegressor',
#   'best_score': 0.5111309314222771,
#   'best_params': {}},
#  {'model': 'XGBRFRegressor',
#   'best_score': 0.5324152437048296,
#   'best_params': {}}]

# %%
model_params = {'DecisionTreeRegressor':{'model':DecisionTreeRegressor(),'params':{'max_depth':[3,4,5,6]}},
               'RandomForestRegressor':{'model':RandomForestRegressor(),'params':{'n_estimators':[5,10,15,20],'max_depth':[3,4,5,6,7]}}}

# %%
scores = []
models = ['DecisionTreeRegressor','RandomForestRegressor']
for model_name in models:
    mp=model_params[model_name]
    gds=GridSearchCV(mp['model'],mp['params'],cv=5,return_train_score=True)
    gds.fit(x,y)
    scores.append({'model':model_name, 'best_score':gds.best_score_ , 'best_params':gds.best_params_})

# %%
scores
# Out:
# [{'model': 'DecisionTreeRegressor',
#   'best_score': 0.49360984651372464,
#   'best_params': {'max_depth': 4}},
#  {'model': 'RandomForestRegressor',
#   'best_score': 0.544049860407554,
#   'best_params': {'max_depth': 5, 'n_estimators': 10}}]

# %% [raw]
# 'KNeighborsRegressor':{'model':KNeighborsRegressor(),'params':{'n_neighbors':[5,10,15,20]}},

# %%
from sklearn.model_selection import KFold ,StratifiedKFold
from sklearn.model_selection import cross_val_score

# %%
dt_score =cross_val_score(DecisionTreeRegressor(),X=x, y=y, cv=4)
rf_score =cross_val_score(RandomForestRegressor(random_state=10),X=x, y=y, cv=4)
XGB_model=cross_val_score(XGBRFRegressor(),X=x, y=y, cv=4)

# %%
print(dt_score)
print(rf_score)
print(XGB_model)
# Out:
# [0.22004638 0.08466434 0.30609705 0.15407105]
# [0.36115157 0.47805395 0.73503161 0.6060493 ]
# [0.37508022 0.49104568 0.73369114 0.58678   ]

# %%
print(dt_score.mean())
print(rf_score.mean())
print(XGB_model.mean())
# Out:
# 0.19121970572406025
# 0.5450716079726523
# 0.5466492572622661

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=33)

# %%
XGBR=XGBRFRegressor()
model=XGBR.fit(x_train,y_train)XGBRFRegressor
model.score(x_test,y_test)
# Out:
# 0.6947763381076535

# %%
RandomForest=RandomForestRegressor(n_estimators=8,random_state=10,)
model=RandomForest.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.6578158964853207

# %%
DecisionTree=DecisionTreeRegressor()
model=DecisionTree.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.4656002516651149
